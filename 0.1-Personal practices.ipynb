# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
housing = pd.read_csv('./datasets/housing/housing.csv')
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
describe = housing.describe()

describe
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing.hist(figsize=(25,25),bins=50)
plt.show()

# %%
train_set, test_set = train_test_split(housing,test_size = 0.2, train_size=0.8, random_state=45)
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3046     -119.28     35.50                34.0       1923.0           379.0
# 6803     -118.13     34.08                40.0       1931.0           449.0
# 10112    -117.94     33.94                30.0       1596.0           307.0
# 3126     -117.79     35.21                 4.0          2.0             2.0
# 5008     -118.33     34.01                47.0       1320.0           259.0
# ...          ...       ...                 ...          ...             ...
# 15021    -117.03     32.79                17.0       7352.0          1699.0
# 6658     -118.12     34.15                22.0       1671.0           480.0
# 18945    -122.03     38.28                15.0       5114.0           833.0
# 2499     -120.39     36.78                11.0       1947.0           488.0
# 19408    -120.91     37.73                31.0        840.0           154.0
#
# ...

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13240    -117.67     34.12                15.0       3162.0           495.0
# 12586    -121.50     38.53                37.0       3642.0           684.0
# 13123    -121.26     38.27                20.0       1314.0           229.0
# 15456    -117.28     33.18                16.0       3002.0           591.0
# 19798    -123.12     40.54                23.0       1091.0           217.0
# ...          ...       ...                 ...          ...             ...
# 16547    -121.22     37.81                20.0       1811.0           352.0
# 16317    -121.32     38.00                22.0       2105.0           521.0
# 12895    -121.33     38.65                24.0       3533.0           741.0
# 6012     -117.78     34.07                18.0       3610.0           772.0
# 6558     -118.11     34.20                36.0       4915.0           725.0
#
# ...

# %%
housing['strata'] = pd.cut(housing['median_income'],bins=[0,1.5,3.0,4.5,6.,np.inf],\
                           labels=['low','median-low','median','median-high','high'])

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing['median_val'] = pd.cut(housing['median_house_value'],
                               bins=[0,100000,110000,200000,264725,np.inf],\
                               labels=['low','median-low','median','median-high','high'])

# %%
housing['median_val'].value_counts()
# Out:
# median         7590
# high           5160
# low            3658
# median-high    3549
# median-low      683
# Name: median_val, dtype: int64

# %%
housing['strata'].hist()
# Out:
# <AxesSubplot:>

# %%
housing['median_val'].hist()
# Out:
# <AxesSubplot:>

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing.plot(kind='scatter',x='latitude',y='longitude',figsize=(25,15),
             grid=True,fontsize=15,alpha=0.2,c = 'median_house_value',
             colorbar=True,cmap='jet')

plt.title(label='Precio de casas en california',fontsize=30)
plt.xlabel('latitude', fontsize=18)
plt.ylabel('longitude', fontsize=18)


circ = plt.Circle((34,-118),0.8,color='black',fill=False)
circ2 = plt.Circle((37.5,-122),0.8,color='black',fill=False)

text1 = plt.text(32.3,-119.5,s='Areas con mayor\ndensidad y costo',fontsize=20)

ax = plt.gca()
ax.add_patch(circ)
ax.add_patch(circ2)

ax.plot()
plt.savefig('precio_casas_en_california.png')
plt.show()
