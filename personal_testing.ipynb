# %%
## normal modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

## Sklearn modules
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Reading and describing housing

# %%
housing = pd.read_csv('../input/california-housing-prices/housing.csv')
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
describe = housing.describe()

describe
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# ## Plotting housing histogram

# %%
housing.hist(figsize=(25,25),bins=50)
plt.show()

# %% [markdown]
# ## Creating income cat

# %%
housing["income_cat"] = pd.cut(housing["median_income"],
                               bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
                               labels=[1, 2, 3, 4, 5])

# %%
housing["income_cat"].hist()
# Out:
# <AxesSubplot:>

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
train_set, test_set = train_test_split(housing,test_size = 0.2, train_size=0.8, random_state=45)

# %% [markdown]
# ## Plotting scatter matrix

# %%
attributes = ["median_house_value", "median_income", "total_rooms",
              "housing_median_age"]
scatter_matrix(housing[attributes], figsize=(25, 15))
plt.show()

# %% [markdown]
# ## Preparing data

# %%
housing["rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing["bedrooms_per_room"] = housing["total_bedrooms"]/housing["total_rooms"]
housing["population_per_household"]=housing["population"]/housing["households"]

# %%
corr_matrix = housing.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8dfdc_row0_col0, #T_8dfdc_row1_col1, #T_8dfdc_row2_col2, #T_8dfdc_row3_col3, #T_8dfdc_row4_col4, #T_8dfdc_row5_col5, #T_8dfdc_row6_col6, #T_8dfdc_row7_col7, #T_8dfdc_row8_col8, #T_8dfdc_row9_col9, #T_8dfdc_row10_col10, #T_8dfdc_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8dfdc_row0_col1, #T_8dfdc_row1_col0, #T_8dfdc_row2_col3, #T_8dfdc_row2_col4, #T_8dfdc_row2_col5, #T_8dfdc_row2_col6, #T_8dfdc_row3_col2, #T_8dfdc_row3_col11, #T_8dfdc_row4_col11, #T_8dfdc_row6_col11, #T_8dfdc_row7_col10, #T_8dfdc_row10_col7, #T_8dfdc_row10_col8, #T_8dfdc_row10_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8dfdc_row0_col2, #T_8dfdc_row2_col9, #T_8dfdc_row5_col8, #T_8dfdc_row11_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8dfdc_row0_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_8dfdc_row0_col4, #T_8dfdc_row4_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_8dfdc_row0_col5, #T_8dfdc_row2_col7, #T_8dfdc_row10_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_8dfdc_row0_col6, #T_8dfdc_row0_col9, #T_8dfdc_row1_col2, #T_8dfdc_row11_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_8dfdc_row0_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_8dfdc_row0_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_8dfdc_row0_col10, #T_8dfdc_row7_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_8dfdc_row0_col11, #T_8dfdc_row1_col11, #T_8dfdc_row4_col2, #T_8dfdc_row10_col11 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_8dfdc_row1_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_8dfdc_row1_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_8dfdc_row1_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8dfdc_row1_col6, #T_8dfdc_row7_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8dfdc_row1_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_8dfdc_row1_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_8dfdc_row1_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_8dfdc_row1_col10, #T_8dfdc_row3_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_8dfdc_row2_col0, #T_8dfdc_row5_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_8dfdc_row2_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_8dfdc_row2_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_8dfdc_row2_col10, #T_8dfdc_row9_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_8dfdc_row2_col11, #T_8dfdc_row6_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_8dfdc_row3_col0, #T_8dfdc_row3_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_8dfdc_row3_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8dfdc_row3_col4, #T_8dfdc_row4_col3 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_8dfdc_row3_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_8dfdc_row3_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_8dfdc_row3_col9, #T_8dfdc_row6_col7 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_8dfdc_row3_col10 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_8dfdc_row4_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_8dfdc_row4_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_8dfdc_row4_col5 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_8dfdc_row4_col6, #T_8dfdc_row6_col4 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_8dfdc_row4_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_8dfdc_row4_col8, #T_8dfdc_row5_col9, #T_8dfdc_row7_col6, #T_8dfdc_row9_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_8dfdc_row4_col10 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_8dfdc_row5_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_8dfdc_row5_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_8dfdc_row5_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_8dfdc_row5_col4 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_8dfdc_row5_col6, #T_8dfdc_row6_col5 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_8dfdc_row5_col7, #T_8dfdc_row11_col10 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_8dfdc_row5_col10, #T_8dfdc_row8_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_8dfdc_row5_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_8dfdc_row6_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_8dfdc_row6_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_8dfdc_row6_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_8dfdc_row6_col8, #T_8dfdc_row10_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_8dfdc_row6_col9, #T_8dfdc_row7_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_8dfdc_row6_col10, #T_8dfdc_row10_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_8dfdc_row7_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8dfdc_row7_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_8dfdc_row7_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_8dfdc_row7_col8 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_8dfdc_row7_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_8dfdc_row7_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_8dfdc_row8_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_8dfdc_row8_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_8dfdc_row8_col3, #T_8dfdc_row9_col3, #T_8dfdc_row10_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_8dfdc_row8_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_8dfdc_row8_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_8dfdc_row8_col6, #T_8dfdc_row10_col6, #T_8dfdc_row11_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_8dfdc_row8_col7 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_8dfdc_row8_col9 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_8dfdc_row8_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_8dfdc_row8_col11 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_8dfdc_row9_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_8dfdc_row9_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_8dfdc_row9_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_8dfdc_row9_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_8dfdc_row9_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_8dfdc_row9_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_8dfdc_row9_col10 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_8dfdc_row9_col11 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_8dfdc_row10_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_8dfdc_row10_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_8dfdc_row11_col0, #T_8dfdc_row11_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_8dfdc_row11_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_8dfdc_row11_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_8dfdc_row11_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8dfdc_row11_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_8dfdc_row11_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# </style>
# <table id="T_8dfdc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >longitude</th>
#       <th class="col_heading level0 col1" >latitude</th>
#       <th class="col_heading level0 col2" >housing_median_age</th>
#       <th class="col_heading level0 col3" >total_rooms</th>
#       <th class="col_heading level0 col4" >total_bedrooms</th>
#       <th class="col_heading level0 col5" >population</th>
#       <th class="col_heading level0 col6" >households</th>
#       <th class="col_heading level0 col7" >median_income</th>
#       <th class="col_heading level0 col8" >median_house_value</th>
#       <th class="col_heading level0 col9" >rooms_per_household</th>
#       <th class="col_heading level0 col10" >bedrooms_per_room</th>
#       <th class="col_heading level0 col11" >population_per_househol

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.688075
# rooms_per_household         0.151948
# total_rooms                 0.134153
# housing_median_age          0.105623
# households                  0.065843
# total_bedrooms              0.049686
# population_per_household   -0.023737
# population                 -0.024650
# longitude                  -0.045967
# latitude                   -0.144160
# bedrooms_per_room          -0.255880
# Name: median_house_value, dtype: float64

# %% [markdown]
# ## Prepare for data machine learning algos

# %%
housing = strat_train_set.drop("median_house_value", axis=1) # drop labels for training set
housing_labels = strat_train_set["median_house_value"].copy()

# %% [markdown]
# ## Sklearn linear regression

# %%
imputer = SimpleImputer(strategy="median")


housing_num = housing.drop("ocean_proximity", axis=1)
imputer.fit(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
X = imputer.transform(housing_num)
housing_tr = pd.DataFrame(X, columns=housing_num.columns,
                          index=housing.index)

# %%
housing_tr
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  income_cat
# 12655      2237.0       706.0         2.1736         2.0
# 15502      2015.0       768.0         6.3373         5.0
# 2908        667.0       300.0         2.8750         2.0
# 14053       898.0       483.0         2.2264         2.0
# 20496      1837.0       580.0         4.4964         3.0
# ...           ...         ...            ...         ...
# 15174      2026.0      1001.0         5.0900         4.0
# 12661      4769.0      1418.0         2.8139         2.0
# 19263       458.0       172.0         3.1797         3.0
# 19140      1208.0       501.0         4.1964         3.0
# 19773       625.0       197.0         3.1319         3.0
#
# [16512 rows x 9 columns]

# %% [markdown]
# ## Handling categorical values
